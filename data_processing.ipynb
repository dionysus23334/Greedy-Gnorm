# %%
from datasets import load_dataset

def get_sentiment_classification(language):
    # language: english,chinese,german,french,indonesian,spanish,japenese
    ds = load_dataset("tyqiangz/multilingual-sentiments", language)
    return ds

ds = get_sentiment_classification('english')

# %%
ds['test'][0]
# Out:
# {'text': 'Trying to have a conversation with my dad about vegetarianism is the most pointless infuriating thing ever #caveman ',
#  'source': 'sem_eval_2017',
#  'label': 2}
